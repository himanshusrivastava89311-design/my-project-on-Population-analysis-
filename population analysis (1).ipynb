# %%
#load data
import pandas as pd
def load_data(filename):
    df= pd.read_csv("world_population_by_country_2026.csv")
    return df
df=load_data("world_population_by_country_2026.csv")

df.head
# Out:
# <bound method NDFrame.head of      Rank           Country  Population_2026  Yearly_Change  Net_Change  \
# 0       1             India       1476625576           0.87  12760051.0
# 1       2             China       1412914089          -0.22  -3182005.0
# 2       3     United States        349035494           0.51   1759687.0
# 3       4         Indonesia        287886782           0.76   2165546.0
# 4       5          Pakistan        259299791           1.60   4080237.0
# ..    ...               ...              ...            ...         ...
# 228   229        Montserrat             4328          -0.71       -31.0
# 229   230  Falkland Islands             3465          -0.12        -4.0
# 230   231           Tokelau             2691           3.18        83.0
# 231   232              Niue             1822           0.05         1.0
# 232   233          Holy See              506           1.00         5.0
#
# ...

# %%
import matplotlib.pyplot as plt
plt.style.use("dark_background")
year=[1960,1965,1970,1975,1980,1985,1990,1995,2000,2005,2010,2015,2020,2026]
population=[435990338,490140146,545864268,611309535,687354025,772647793,864972221,960301044,1057922733,1154676322,1243481564,1328024498,1402617695,1470000000]
plt.figure(figsize=(12,5))
plt.bar(year,population)
plt.xticks(year,rotation=45)
plt.xlabel=("year") # Changed from plt.xlabel=("year") to plt.xlabel("year")
plt.ylabel=("population") # Changed from plt.ylabel=("population") to plt.ylabel("population")
plt.title("India population")
plt.show()

# %%
import matplotlib.pyplot as plt
year=[2026]
countries=['India 2026','Foreign 2026']
population=[1470000000,6830000000]
colors=["blue","green"]
plt.pie(population,labels=countries,autopct='%1.1f%%',colors=colors)
plt.title("population")
plt.show( )

# %%
#This graph shows that India accounts for 17.7%of the world population,
#makingg it the most populated country in the world.
